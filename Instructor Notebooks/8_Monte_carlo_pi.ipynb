# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

circle = plt.Circle((0, 0), 1, edgecolor='r', facecolor='none')
ax.add_patch(circle)

plt.show()

# %%
# Plotting the points
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

'''
x = random.uniform(-1, 1)
y = random.uniform(-1, 1)
plt.scatter([x], [y])
'''

circle = plt.Circle((0, 0), 1, edgecolor='r', facecolor='none')
ax.add_patch(circle)

plt.show()

# %%
# Plotting the points
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

x = random.uniform(-1, 1)
y = random.uniform(-1, 1)

'''
x_inside = []
y_inside = []
x_outside = []
y_outside = []

if x**2 + y**2 <= 1:
    x_inside.append(x)
    y_inside.append(y)
else:
    x_outside.append(x)
    y_outside.append(y)

plt.scatter([x_inside], [y_inside], s=3, color='red')
plt.scatter([x_outside], [y_outside], s=3, color='blue')
'''

# Plot the circle
circle = plt.Circle((0, 0), 1, edgecolor='r', facecolor='none')
ax.add_patch(circle)

plt.show()

# %%
num_points = 10000

fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.xlim(-1, 1)
plt.ylim(-1, 1)

#1. x = random.uniform(-1, 1)
#1. y = random.uniform(-1, 1)

x_inside = []
y_inside = []
x_outside = []
y_outside = []

# inside_circle = 0

for i in range(num_points):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x**2 + y**2) <= 1:
        # inside_circle += 1
        x_inside.append(x)
        y_inside.append(y)
    else:
        x_outside.append(x)
        y_outside.append(y)

plt.scatter([x_inside], [y_inside], s=3, color='red')
plt.scatter([x_outside], [y_outside], s=3, color='blue')

circle = plt.Circle((0, 0), 1, edgecolor='r', facecolor='none')
ax.add_patch(circle)

plt.show()

# %%
# Estimate of π
pi_estimate = 4 * inside_circle / num_points
print(f"Estimated value of π: {pi_estimate}")
# Out:
# Estimated value of π: 3.1628
