# %% [markdown]
# # Exploring AoT Data
#
# One of the most important steps in doing science with data is to familiarize yourself with the data, including
# * Getting a first look at the data.
# * How is it structured?
# * Looking more closely at the data.
# * Filtering the data that you are interested in.

# %% [markdown]
# ## Getting a First Look

# %% [markdown]
# #### Import Pandas
#
# We will use Pandas to read in the data file and work with it.

# %%
import pandas as pd

# %% [markdown]
# #### Read in the .csv file
#
# Use the `read_csv` function in Pandas to read in the comma seperated variable dataset (.csv file).

# %%
data = pd.read_csv("../data/AoT_Chicago.complete.recent.csv")

# %% [markdown]
# We put the data into a variable called `data`. In Pandas, it is stored as a "dataframe". To see it, we simply "call" that variable.

# %%
# print the dataframe
data
# Out:
#                 timestamp       node_id   subsystem         sensor  \
# 0     2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1     2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 2     2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3     2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 4     2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# ...                   ...           ...         ...            ...
# 4677  2021/03/20 01:01:23  001e0610ee36    metsense        pr103j2
# 4678  2021/03/20 01:01:23  001e0610ee36    metsense  spv1840lr5h_b
# 4679  2021/03/20 01:01:23  001e0610ee36    metsense         tmp112
# 4680  2021/03/20 01:01:23  001e0610ee36    metsense       tsl250rd
# 4681  2021/03/20 01:01:23  001e0610ee36    metsense         tsys01
#
#              parameter value_raw  value_hrf
# 0            intensity         8      0.643
# 1             humidity      9272       56.6
# 2          temperature     22704      17.17
# 3     magnetic_field_x      -177   -160.909
# 4     magnetic_field_y     -1700  -1545.455
# ...                ...       ...        ...
# 4677       temperature       686        6.9
# 4678         intensity       NaN      56.72
# 4679       temperature       873       6.81
# 4680         intensity         0        0.0
# 4681       temperature   9280204       6.97
#
# [4682 rows x 7 columns]

# %% [markdown]
# #### Just view the first few entries

# %%
# print the first few entries
data.head()
# Out:
#              timestamp       node_id   subsystem         sensor  \
# 0  2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1  2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 2  2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3  2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 4  2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
#
#           parameter value_raw  value_hrf
# 0         intensity         8      0.643
# 1          humidity      9272       56.6
# 2       temperature     22704      17.17
# 3  magnetic_field_x      -177   -160.909
# 4  magnetic_field_y     -1700  -1545.455

# %% [markdown]
# #### Just view the last few entries

# %%
# print the last few entries
data.tail()
# Out:
#                 timestamp       node_id subsystem         sensor    parameter  \
# 4677  2021/03/20 01:01:23  001e0610ee36  metsense        pr103j2  temperature
# 4678  2021/03/20 01:01:23  001e0610ee36  metsense  spv1840lr5h_b    intensity
# 4679  2021/03/20 01:01:23  001e0610ee36  metsense         tmp112  temperature
# 4680  2021/03/20 01:01:23  001e0610ee36  metsense       tsl250rd    intensity
# 4681  2021/03/20 01:01:23  001e0610ee36  metsense         tsys01  temperature
#
#      value_raw value_hrf
# 4677       686       6.9
# 4678       NaN     56.72
# 4679       873      6.81
# 4680         0       0.0
# 4681   9280204      6.97

# %% [markdown]
# ## How is it structured?

# %%
data.shape
# Out:
# (4682, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4682 entries, 0 to 4681
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  4682 non-null   object
#  1   node_id    4682 non-null   object
#  2   subsystem  4682 non-null   object
#  3   sensor     4682 non-null   object
#  4   parameter  4682 non-null   object
#  5   value_raw  4538 non-null   object
#  6   value_hrf  4636 non-null   object
# dtypes: object(7)
# memory usage: 256.2+ KB

# %% [markdown]
# ## Looking more closely at the data

# %% [markdown]
# We can get a little more detailed summary of the data using the `.describe()` method.

# %%
data.describe()
# Out:
#                   timestamp       node_id subsystem   sensor  parameter  \
# count                  4682          4682      4682     4682       4682
# unique                  184             3         3       18         23
# top     2021/03/20 00:51:47  001e0611804d  metsense  pms7003  intensity
# freq                     62          2627      2246      852       1100
#
#        value_raw value_hrf
# count       4538      4636
# unique       646       538
# top        65535         0
# freq        1065       852

# %% [markdown]
# In order to drill a little deaper, we can see the unique entries using the `.drop_duplicates()` method.

# %%
data.drop_duplicates("node_id")
# Out:
#               timestamp       node_id   subsystem         sensor  parameter  \
# 0   2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020  intensity
# 25  2021/03/20 00:31:21  001e0611804d  lightsense  apds_9006_020  intensity
# 62  2021/03/20 00:31:27  001e0610fb4c    metsense        hih4030   humidity
#
#    value_raw value_hrf
# 0          8     0.643
# 25     65535  5267.409
# 62       518     78.56

# %% [markdown]
# Your probably wondering if `drop_duplicates()` deleted a bunch of data.

# %%
data
# Out:
#                 timestamp       node_id   subsystem         sensor  \
# 0     2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1     2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 2     2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3     2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 4     2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# ...                   ...           ...         ...            ...
# 4677  2021/03/20 01:01:23  001e0610ee36    metsense        pr103j2
# 4678  2021/03/20 01:01:23  001e0610ee36    metsense  spv1840lr5h_b
# 4679  2021/03/20 01:01:23  001e0610ee36    metsense         tmp112
# 4680  2021/03/20 01:01:23  001e0610ee36    metsense       tsl250rd
# 4681  2021/03/20 01:01:23  001e0610ee36    metsense         tsys01
#
#              parameter value_raw  value_hrf
# 0            intensity         8      0.643
# 1             humidity      9272       56.6
# 2          temperature     22704      17.17
# 3     magnetic_field_x      -177   -160.909
# 4     magnetic_field_y     -1700  -1545.455
# ...                ...       ...        ...
# 4677       temperature       686        6.9
# 4678         intensity       NaN      56.72
# 4679       temperature       873       6.81
# 4680         intensity         0        0.0
# 4681       temperature   9280204       6.97
#
# [4682 rows x 7 columns]

# %% [markdown]
# #### How many different sensors do we have? (Student)

# %%
data.drop_duplicates("sensor")
# Out:
#               timestamp       node_id   subsystem         sensor  \
# 0   2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1   2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3   2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 6   2021/03/20 00:31:19  001e0610ee36  lightsense         ml8511
# 7   2021/03/20 00:31:19  001e0610ee36  lightsense       mlx75305
# 8   2021/03/20 00:31:19  001e0610ee36  lightsense         tmp421
# 9   2021/03/20 00:31:19  001e0610ee36  lightsense       tsl250rd
# 10  2021/03/20 00:31:19  001e0610ee36  lightsense       tsl260rd
# 11  2021/03/20 00:31:19  001e0610ee36    metsense         bmp180
# 13  2021/03/20 00:31:19  001e0610ee36    metsense        hih4030
# 14  2021/03/20 00:31:19  001e0610ee36    metsense         htu21d
# 16  2021/03/20 00:31:19  001e0610ee36    metsense       metsense
# 17  2021/03/20 00:31:19  001e0610ee36    metsense       mma8452q
# 20  2021/03/20 00:31:19  001e0610ee36    metsense        pr103j2
# 21  2021/03/20 00:31:19  001e0610ee36    metsense  spv1840lr5h_b
# 22  2021/03/20 00:31:19  001e0610ee36    metsense         tmp112
# 24  2021/03/20 00:31:19  001e0610ee36    metsense         tsys01
# 50  2021/03/20 00:31:21  001e0611804d   plantower        pms7003
#
#            parameter     value_raw     value_hrf
# 0          intensity             8         0.643
# 1           humidity          9272          56.6
# 3   magnetic_field_x          -177      -160.909
# 6          intensity          9688        45.473
# 7          intensity          1126        11.943
# 8        temperature          3392         13.25
# 9          intensity          9689        23.564
# 10         intensity          1126         2.926
# 11          pressure      11444704       1051.96
# 13          humidity           469         71.22
# 14          humidity         47738         85.05
# 16                id  011cd1141800  011cd1141800
# 17    acceleration_x         65328       -12.695
# 20       temperature           691          7.35
# 21         intensity           NaN         56.72
# 22       temperature           929          7.25
# 24       temperature       9292892          7.42
# 50     10um_particle             0             0

# %% [markdown]
# If we want to create a new set of data, we can assign our operation to a variable.

# %%
sensor = data.drop_duplicates("sensor")
sensor
# Out:
#               timestamp       node_id   subsystem         sensor  \
# 0   2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1   2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3   2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 6   2021/03/20 00:31:19  001e0610ee36  lightsense         ml8511
# 7   2021/03/20 00:31:19  001e0610ee36  lightsense       mlx75305
# 8   2021/03/20 00:31:19  001e0610ee36  lightsense         tmp421
# 9   2021/03/20 00:31:19  001e0610ee36  lightsense       tsl250rd
# 10  2021/03/20 00:31:19  001e0610ee36  lightsense       tsl260rd
# 11  2021/03/20 00:31:19  001e0610ee36    metsense         bmp180
# 13  2021/03/20 00:31:19  001e0610ee36    metsense        hih4030
# 14  2021/03/20 00:31:19  001e0610ee36    metsense         htu21d
# 16  2021/03/20 00:31:19  001e0610ee36    metsense       metsense
# 17  2021/03/20 00:31:19  001e0610ee36    metsense       mma8452q
# 20  2021/03/20 00:31:19  001e0610ee36    metsense        pr103j2
# 21  2021/03/20 00:31:19  001e0610ee36    metsense  spv1840lr5h_b
# 22  2021/03/20 00:31:19  001e0610ee36    metsense         tmp112
# 24  2021/03/20 00:31:19  001e0610ee36    metsense         tsys01
# 50  2021/03/20 00:31:21  001e0611804d   plantower        pms7003
#
#            parameter     value_raw     value_hrf
# 0          intensity             8         0.643
# 1           humidity          9272          56.6
# 3   magnetic_field_x          -177      -160.909
# 6          intensity          9688        45.473
# 7          intensity          1126        11.943
# 8        temperature          3392         13.25
# 9          intensity          9689        23.564
# 10         intensity          1126         2.926
# 11          pressure      11444704       1051.96
# 13          humidity           469         71.22
# 14          humidity         47738         85.05
# 16                id  011cd1141800  011cd1141800
# 17    acceleration_x         65328       -12.695
# 20       temperature           691          7.35
# 21         intensity           NaN         56.72
# 22       temperature           929          7.25
# 24       temperature       9292892          7.42
# 50     10um_particle             0             0

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# You can think of the data frame from two perspectives: columns and rows. Columns are much easier to work with because they are arrays, meaning all the elements in a column are the same datatype (or they should be).
#
# #### Working with Columns

# %% [markdown]
# We can filter certain columns by using brackets around the column names, but we need to pass it as a list of column names, which needs to be in its own set of brackets. This is how we reference columns: `dataset_name[['column_name1', 'column_name2, ...]]`

# %%
node_id = data[['node_id', 'sensor']]

# %%
node_id
# Out:
#            node_id         sensor
# 0     001e0610ee36  apds_9006_020
# 1     001e0610ee36        hih6130
# 2     001e0610ee36        hih6130
# 3     001e0610ee36       hmc5883l
# 4     001e0610ee36       hmc5883l
# ...            ...            ...
# 4677  001e0610ee36        pr103j2
# 4678  001e0610ee36  spv1840lr5h_b
# 4679  001e0610ee36         tmp112
# 4680  001e0610ee36       tsl250rd
# 4681  001e0610ee36         tsys01
#
# [4682 rows x 2 columns]

# %% [markdown]
# #### Renaming Columns
#
# Sometimes the original column names are confusing. You can change them by setting a list of new column names to `data.columns`

# %%
data.columns = ['Timestamp','Node', 'Subsystem', 'Sensor_Name', 'Measurement', 'Raw_Value', 'Human_Readable']

# %%
data.head()
# Out:
#              Timestamp          Node   Subsystem    Sensor_Name  \
# 0  2021/03/20 00:31:19  001e0610ee36  lightsense  apds_9006_020
# 1  2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 2  2021/03/20 00:31:19  001e0610ee36  lightsense        hih6130
# 3  2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
# 4  2021/03/20 00:31:19  001e0610ee36  lightsense       hmc5883l
#
#         Measurement Raw_Value Human_Readable
# 0         intensity         8          0.643
# 1          humidity      9272           56.6
# 2       temperature     22704          17.17
# 3  magnetic_field_x      -177       -160.909
# 4  magnetic_field_y     -1700      -1545.455

# %% [markdown]
# ### What about rows?
#
# Rows are a little trickier to reference because they are not arrays. In columns, we can reference the name of the columns that we are interested in. Also, the elements in a column are the same data type. Since rows contain the elements of several different arrays, they can contain multiple data types and require a different way of thinking. We can filter rows two ways: by index or by label.
#
# For the `iloc` method, you can pass a number `[5]`, range of numbers `[5:9]`, list `[23, 45, 87]`. These values correspond to the bold index values in the first column.

# %% [markdown]
# `iloc`

# %%
# pass a value
data.iloc[45]
# Out:
# Timestamp         2021/03/20 00:31:21
# Node                     001e0611804d
# Subsystem                    metsense
# Sensor_Name                   pr103j2
# Measurement               temperature
# Raw_Value                         664
# Human_Readable                   4.95
# Name: 45, dtype: object

# %%
# pass a range
data.iloc[16:19]
# Out:
#               Timestamp          Node Subsystem Sensor_Name     Measurement  \
# 16  2021/03/20 00:31:19  001e0610ee36  metsense    metsense              id
# 17  2021/03/20 00:31:19  001e0610ee36  metsense    mma8452q  acceleration_x
# 18  2021/03/20 00:31:19  001e0610ee36  metsense    mma8452q  acceleration_y
#
#        Raw_Value Human_Readable
# 16  011cd1141800   011cd1141800
# 17         65328        -12.695
# 18         49392       -985.352

# %%
# pass a list
data.iloc[[23, 45, 87]]
# Out:
#               Timestamp          Node Subsystem Sensor_Name  Measurement  \
# 23  2021/03/20 00:31:19  001e0610ee36  metsense    tsl250rd    intensity
# 45  2021/03/20 00:31:21  001e0611804d  metsense     pr103j2  temperature
# 87  2021/03/20 00:31:44  001e0610ee36  metsense     pr103j2  temperature
#
#    Raw_Value Human_Readable
# 23         0            0.0
# 45       664           4.95
# 87       686            6.9

# %% [markdown]
# `loc`

# %% [markdown]
# The `loc` method allows you to search for labels within the columns. You can use values, booleans, and conditionals.

# %%
# pass a value
data.loc[34]
# Out:
# Timestamp         2021/03/20 00:31:21
# Node                     001e0611804d
# Subsystem                  lightsense
# Sensor_Name                  tsl250rd
# Measurement                 intensity
# Raw_Value                       65535
# Human_Readable                159.907
# Name: 34, dtype: object

# %%
# pass a conditional
data.loc[data['Measurement'] == 'humidity']
# Out:
#                 Timestamp          Node   Subsystem Sensor_Name Measurement  \
# 1     2021/03/20 00:31:19  001e0610ee36  lightsense     hih6130    humidity
# 13    2021/03/20 00:31:19  001e0610ee36    metsense     hih4030    humidity
# 14    2021/03/20 00:31:19  001e0610ee36    metsense      htu21d    humidity
# 26    2021/03/20 00:31:21  001e0611804d  lightsense     hih6130    humidity
# 38    2021/03/20 00:31:21  001e0611804d    metsense     hih4030    humidity
# ...                   ...           ...         ...         ...         ...
# 4629  2021/03/20 01:01:09  001e0611804d    metsense      htu21d    humidity
# 4652  2021/03/20 01:01:21  001e0610fb4c    metsense     hih4030    humidity
# 4658  2021/03/20 01:01:23  001e0610ee36  lightsense     hih6130    humidity
# 4670  2021/03/20 01:01:23  001e0610ee36    metsense     hih4030    humidity
# 4671  2021/03/20 01:01:23  001e0610ee36    metsense      htu21d    humidity
#
#      Raw_Value Human_Readable
# 1         9272           56.6
# 13         469          71.22
# 14       47738          85.05
# 26       65535          100.0
# 38         420          63.88
# ...        ...            ...
# 4629     65535         118.99
# 4652       518          78.56
# 4658      9304          56.79
# 4670       466          70.77
# 4671     52370          93.88
#
# [478 rows x 7 columns]

# %%
# pass multiple conditionals
data.loc[(data['Measurement'] == 'humidity') & (data['Sensor_Name'] == 'htu21d')]
# Out:
#                 Timestamp          Node Subsystem Sensor_Name Measurement  \
# 14    2021/03/20 00:31:19  001e0610ee36  metsense      htu21d    humidity
# 39    2021/03/20 00:31:21  001e0611804d  metsense      htu21d    humidity
# 81    2021/03/20 00:31:44  001e0610ee36  metsense      htu21d    humidity
# 106   2021/03/20 00:31:47  001e0611804d  metsense      htu21d    humidity
# 148   2021/03/20 00:32:09  001e0610ee36  metsense      htu21d    humidity
# ...                   ...           ...       ...         ...         ...
# 4537  2021/03/20 01:00:33  001e0610ee36  metsense      htu21d    humidity
# 4567  2021/03/20 01:00:44  001e0611804d  metsense      htu21d    humidity
# 4604  2021/03/20 01:00:58  001e0610ee36  metsense      htu21d    humidity
# 4629  2021/03/20 01:01:09  001e0611804d  metsense      htu21d    humidity
# 4671  2021/03/20 01:01:23  001e0610ee36  metsense      htu21d    humidity
#
#      Raw_Value Human_Readable
# 14       47738          85.05
# 39       65535         118.99
# 81       48202          85.93
# 106      65535         118.99
# 148      48518          86.54
# ...        ...            ...
# 4537     52250          93.66
# 4567     65535         118.99
# 4604     52330          93.81
# 4629     65535         118.99
# 4671     52370          93.88
#
# [144 rows x 7 columns]
