# %% [markdown]
# # Exlploring AoT Data (Lecture)

# %% [markdown]
# ### Import Pandas
#
# We will use Pandas to read in the data file and manipulate it. Numpy also has a lot of methods for working with data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read in the .csv file
#
# Use the read_csv function in Pandas to read in comma seperated variable datasets (.csv files).

# %%
# Path to file and filename need to be updated to reflect where data is currently stored 
data = pd.read_csv("../../Datasets/AoT/July18_2019.csv")

# %% [markdown]
# ### Print the data

# %%
data
# Out:
#               timestamp       node_id subsystem   sensor    parameter  \
# 0   2019/07/18 14:00:00  001e0610ee36  metsense  pr103j2  temperature
# 1   2019/07/18 14:00:00  001e06114fd4  metsense  pr103j2  temperature
# 2   2019/07/18 14:00:01  001e0610ba13  metsense  pr103j2  temperature
# 3   2019/07/18 14:00:02  001e0610ee61  metsense  pr103j2  temperature
# 4   2019/07/18 14:00:02  001e06113ad8  metsense  pr103j2  temperature
# 5   2019/07/18 14:00:02  001e0611462f  metsense  pr103j2  temperature
# 6   2019/07/18 14:00:03  001e0610bbf9  metsense  pr103j2  temperature
# 7   2019/07/18 14:00:03  001e061146cb  metsense  pr103j2  temperature
# 8   2019/07/18 14:00:04  001e0610ba15  metsense  pr103j2  temperature
# 9   2019/07/18 14:00:04  001e0610e537  metsense  pr103j2  temperature
# 10  2019/07/18 14:00:04  001e061130f4  metsense  pr103j2  temperature
# 11  2019/07/18 14:00:05  001e0610f732  metsense  pr103j2  temperature
# 12  2019/07/18 14:00:05  001e06113cf1  metsense  pr103j2  temperature
# 13  2019/07/18 14:00:05  001e061146bc  metsense  pr103j2  temperature
# 14  2019/07/18 14:00:05  001e0611536c  metsense  pr103j2  temperature
# 15  2019/07/18 14:00:05  001e06118501  metsense  pr103j2  temperature
# 16  2019/07/18 14:00:07  001e0610e835  metsense  pr103j2  temperature
# 17  2019/07/18 14:00:07  001e06113a24  metsense  pr103j2  temperature
# 18  2019/07/18 14:00:07  001e06115365  metsense  pr103j2  temperature
# 19  2019/07/18 14:00:07  001e0611856d  metsense  pr103j2  temperature
# 20  2019/07/18 14:00:08  001e061183f3  metsense  pr103j2  temperature
# 21  2019/07/18 14:00:08  001e061183f5  metsense  pr103j2  temperature
# 22  2019/07/18 14:00:10  001e0610f02f  metsense  pr103j2  temperature
# 23  2019/07/18 14:00:11  001e0610ee5d  metsense  pr103j2  temperature
# 24  2019/07/18 14:00:11  001e0610f05c  metsense  pr103j2  temperature
# 25  2019/07/18 14:00:11  001e06117b44  metsense  pr103j2  temperature
# 26  2019/07/18 14:00:12  001e061182a7  metsense  pr103j2  temperature
# 27  2019/07/18 14:00:13  001e0610bc10  metsense  pr103j2  temperature
# 28  2019/07/18 14:00:13  001e061183eb  metsense  pr103j2  temperature
# 29  2019/07/18 14:00:15  001e0610eef2  metsense  pr103j2  temperature
# 30  2019/07/18 14:00:16  001e06113d20  metsense  pr103j2  temperature
# 31  2019/07/18 14:00:16  001e061146ba  metsense  pr103j2  temperature
# 32  2019/07/18 14:00:17  001e0610ba46  metsense  pr103j2  temperature
# 33  2019/07/18 14:00:21  001e0610f703  metsense  pr103j2  temperature
# 34  2019/07/18 14:00:21  001e061144be  metsense  pr103j2  temperature
# 35  2019/07/18 14:00:22  001e06113d22  metsense  pr103j2  temperature
# 36  2019/07/18 14:00:22  001e06118182  metsense  pr103j2  temperature
# 37  2019/07/18 14:00:23  001e06113ace  metsense  pr103j2  temperature
# 38  2019/07/18 14:00:23  001e0611537d  metsense  pr103j2  temperature
# 39  2019/07/18 14:00:24  001e0610ee43  metsense  pr103j2  temperature
# 40  2019/07/18 14:00:30  001e0611441e  metsense  pr103j2  temperature
#
#     value_raw  value_hrf
# 0         840      24.45
# 1         839      24.30
# 2         853      26.45
# 3         850      26.00
# 4         837      24.00
# 5         810      20.20
# 6         845      25.20
# 7         835      23.70
# 8          24        NaN
# 9         833      23.40
# 10        843      24.90
# 11        827      22.55
# 12        837      24.00
# 13        819      21.40
# 14        836      23.85
# 15        859      27.45
# 16        843      24.90
# 17        850      26.00
# 18        849      25.85
# 19        855      26.80
# 20        843      24.90
# 21        853      26.45
# 22        833      23.40
# 23        840      24.45
# 24        844      25.05
# 25        842      24.75
# 26        860      27.65
# 27        809      20.10
# 28        837      24.00
# 29        822      21.85
# 30        805      19.55
# 31        830      22.95
# 32        840      24.45
# 33        821      21.70
# 34        866      28.65
# 35        839      24.30
# 36        845      25.20
# 37        831      23.10
# 38        845      25.20
# 39        846      25.35
# 40        835      23.70

# %% [markdown]
# ### Just view the first few entries

# %%
data.head()
# Out:
#              timestamp       node_id subsystem   sensor    parameter  \
# 0  2019/07/18 14:00:00  001e0610ee36  metsense  pr103j2  temperature
# 1  2019/07/18 14:00:00  001e06114fd4  metsense  pr103j2  temperature
# 2  2019/07/18 14:00:01  001e0610ba13  metsense  pr103j2  temperature
# 3  2019/07/18 14:00:02  001e0610ee61  metsense  pr103j2  temperature
# 4  2019/07/18 14:00:02  001e06113ad8  metsense  pr103j2  temperature
#
#    value_raw  value_hrf
# 0        840      24.45
# 1        839      24.30
# 2        853      26.45
# 3        850      26.00
# 4        837      24.00

# %% [markdown]
# ### Just view the last few entries

# %%
data.tail()
# Out:
#               timestamp       node_id subsystem   sensor    parameter  \
# 36  2019/07/18 14:00:22  001e06118182  metsense  pr103j2  temperature
# 37  2019/07/18 14:00:23  001e06113ace  metsense  pr103j2  temperature
# 38  2019/07/18 14:00:23  001e0611537d  metsense  pr103j2  temperature
# 39  2019/07/18 14:00:24  001e0610ee43  metsense  pr103j2  temperature
# 40  2019/07/18 14:00:30  001e0611441e  metsense  pr103j2  temperature
#
#     value_raw  value_hrf
# 36        845      25.20
# 37        831      23.10
# 38        845      25.20
# 39        846      25.35
# 40        835      23.70

# %% [markdown]
# ## Get a Summary of the Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  41 non-null     object
#  1   node_id    41 non-null     object
#  2   subsystem  41 non-null     object
#  3   sensor     41 non-null     object
#  4   parameter  41 non-null     object
#  5   value_raw  41 non-null     int64
#  6   value_hrf  40 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.4+ KB

# %%
data.shape
# Out:
# (41, 7)

# %% [markdown]
# ### Are we working with a complete data set?
#
# A good way to check is to count the number of elements in each column.

# %%
data.count()
# Out:
# timestamp    41
# node_id      41
# subsystem    41
# sensor       41
# parameter    41
# value_raw    41
# value_hrf    40
# dtype: int64

# %% [markdown]
# ### How many nodes are in this data set?
#
# We can see the unique entries by eliminating duplicates.

# %%
data.drop_duplicates("node_id")
# Out:
#               timestamp       node_id subsystem   sensor    parameter  \
# 0   2019/07/18 14:00:00  001e0610ee36  metsense  pr103j2  temperature
# 1   2019/07/18 14:00:00  001e06114fd4  metsense  pr103j2  temperature
# 2   2019/07/18 14:00:01  001e0610ba13  metsense  pr103j2  temperature
# 3   2019/07/18 14:00:02  001e0610ee61  metsense  pr103j2  temperature
# 4   2019/07/18 14:00:02  001e06113ad8  metsense  pr103j2  temperature
# 5   2019/07/18 14:00:02  001e0611462f  metsense  pr103j2  temperature
# 6   2019/07/18 14:00:03  001e0610bbf9  metsense  pr103j2  temperature
# 7   2019/07/18 14:00:03  001e061146cb  metsense  pr103j2  temperature
# 8   2019/07/18 14:00:04  001e0610ba15  metsense  pr103j2  temperature
# 9   2019/07/18 14:00:04  001e0610e537  metsense  pr103j2  temperature
# 10  2019/07/18 14:00:04  001e061130f4  metsense  pr103j2  temperature
# 11  2019/07/18 14:00:05  001e0610f732  metsense  pr103j2  temperature
# 12  2019/07/18 14:00:05  001e06113cf1  metsense  pr103j2  temperature
# 13  2019/07/18 14:00:05  001e061146bc  metsense  pr103j2  temperature
# 14  2019/07/18 14:00:05  001e0611536c  metsense  pr103j2  temperature
# 15  2019/07/18 14:00:05  001e06118501  metsense  pr103j2  temperature
# 16  2019/07/18 14:00:07  001e0610e835  metsense  pr103j2  temperature
# 17  2019/07/18 14:00:07  001e06113a24  metsense  pr103j2  temperature
# 18  2019/07/18 14:00:07  001e06115365  metsense  pr103j2  temperature
# 19  2019/07/18 14:00:07  001e0611856d  metsense  pr103j2  temperature
# 20  2019/07/18 14:00:08  001e061183f3  metsense  pr103j2  temperature
# 21  2019/07/18 14:00:08  001e061183f5  metsense  pr103j2  temperature
# 22  2019/07/18 14:00:10  001e0610f02f  metsense  pr103j2  temperature
# 23  2019/07/18 14:00:11  001e0610ee5d  metsense  pr103j2  temperature
# 24  2019/07/18 14:00:11  001e0610f05c  metsense  pr103j2  temperature
# 25  2019/07/18 14:00:11  001e06117b44  metsense  pr103j2  temperature
# 26  2019/07/18 14:00:12  001e061182a7  metsense  pr103j2  temperature
# 27  2019/07/18 14:00:13  001e0610bc10  metsense  pr103j2  temperature
# 28  2019/07/18 14:00:13  001e061183eb  metsense  pr103j2  temperature
# 29  2019/07/18 14:00:15  001e0610eef2  metsense  pr103j2  temperature
# 30  2019/07/18 14:00:16  001e06113d20  metsense  pr103j2  temperature
# 31  2019/07/18 14:00:16  001e061146ba  metsense  pr103j2  temperature
# 32  2019/07/18 14:00:17  001e0610ba46  metsense  pr103j2  temperature
# 33  2019/07/18 14:00:21  001e0610f703  metsense  pr103j2  temperature
# 34  2019/07/18 14:00:21  001e061144be  metsense  pr103j2  temperature
# 35  2019/07/18 14:00:22  001e06113d22  metsense  pr103j2  temperature
# 36  2019/07/18 14:00:22  001e06118182  metsense  pr103j2  temperature
# 37  2019/07/18 14:00:23  001e06113ace  metsense  pr103j2  temperature
# 38  2019/07/18 14:00:23  001e0611537d  metsense  pr103j2  temperature
# 39  2019/07/18 14:00:24  001e0610ee43  metsense  pr103j2  temperature
# 40  2019/07/18 14:00:30  001e0611441e  metsense  pr103j2  temperature
#
#     value_raw  value_hrf
# 0         840      24.45
# 1         839      24.30
# 2         853      26.45
# 3         850      26.00
# 4         837      24.00
# 5         810      20.20
# 6         845      25.20
# 7         835      23.70
# 8          24        NaN
# 9         833      23.40
# 10        843      24.90
# 11        827      22.55
# 12        837      24.00
# 13        819      21.40
# 14        836      23.85
# 15        859      27.45
# 16        843      24.90
# 17        850      26.00
# 18        849      25.85
# 19        855      26.80
# 20        843      24.90
# 21        853      26.45
# 22        833      23.40
# 23        840      24.45
# 24        844      25.05
# 25        842      24.75
# 26        860      27.65
# 27        809      20.10
# 28        837      24.00
# 29        822      21.85
# 30        805      19.55
# 31        830      22.95
# 32        840      24.45
# 33        821      21.70
# 34        866      28.65
# 35        839      24.30
# 36        845      25.20
# 37        831      23.10
# 38        845      25.20
# 39        846      25.35
# 40        835      23.70

# %% [markdown]
# Your probably wondering if `drop_duplicates()` deleted a bunch of data.

# %%
data.shape
# Out:
# (41, 7)

# %% [markdown]
# ### How many different sensors do we have? (Student)
#
# If we want to create a new set of data, we can assign our operation to a variable.

# %%
sensor_count = data.drop_duplicates("sensor")

# %%
sensor_count.shape
# Out:
# (1, 7)

# %% [markdown]
# ## Obviously, there is an easier way to do this.

# %%
data.describe()
# Out:
#         value_raw  value_hrf
# count   41.000000  40.000000
# mean   818.780488  24.303750
# std    127.924687   2.003279
# min     24.000000  19.550000
# 25%    833.000000  23.400000
# 50%    840.000000  24.450000
# 75%    845.000000  25.237500
# max    866.000000  28.650000

# %% [markdown]
# # Getting the right data

# %% [markdown]
# ## Working with Columns

# %%
data.columns
# Out:
# Index(['timestamp', 'node_id', 'subsystem', 'sensor', 'parameter', 'value_raw',
#        'value_hrf'],
#       dtype='object')

# %% [markdown]
# We can extract columns data by using brackets around the column name. This is how we reference columns: `dataset_name['column name']`

# %%
node_id = data['node_id']      #This is just referencing a single column, which is a series.

# %%
node_id
# Out:
# 0     001e0610ee36
# 1     001e06114fd4
# 2     001e0610ba13
# 3     001e0610ee61
# 4     001e06113ad8
# 5     001e0611462f
# 6     001e0610bbf9
# 7     001e061146cb
# 8     001e0610ba15
# 9     001e0610e537
# 10    001e061130f4
# 11    001e0610f732
# 12    001e06113cf1
# 13    001e061146bc
# 14    001e0611536c
# 15    001e06118501
# 16    001e0610e835
# 17    001e06113a24
# 18    001e06115365
# 19    001e0611856d
# 20    001e061183f3
# 21    001e061183f5
# 22    001e0610f02f
# 23    001e0610ee5d
# 24    001e0610f05c
# 25    001e06117b44
# 26    001e061182a7
# 27    001e0610bc10
# 28    001e061183eb
# 29    001e0610eef2
# 30    001e06113d20
# 31    001e061146ba
# 32    001e0610ba46
# 33    001e0610f703
# 34    001e061144be
# 35    001e06113d22
# 36    001e06118182
# 37    001e06113ace
# 38    001e0611537d
# 39    001e0610ee43
# 40    001e0611441e
# Name: node_id, dtype: object

# %% [markdown]
# What kind of data is node_id?

# %%
type(node_id)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Even though it is a series, it still keeps its index.

# %% [markdown]
# We can extract multiple columns, but we need to pass a list of column names.

# %%
node_id = data[['node_id', 'sensor']]      #This is referencing 2 columns which is an array (dataframe)

# %%
node_id.head()
# Out:
#         node_id   sensor
# 0  001e0610ee36  pr103j2
# 1  001e06114fd4  pr103j2
# 2  001e0610ba13  pr103j2
# 3  001e0610ee61  pr103j2
# 4  001e06113ad8  pr103j2

# %% [markdown]
# This looks different than when we extracted a single column. Let's check the type

# %%
type(node_id)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Why the difference?

# %% [markdown]
# ## Renaming Columns

# %%
data.columns = ['Timestamp','Node', 'Subsystem', 'Sensor_Name', 'Measurement', 'Raw_Value', 'Human_Readable']

# %%
data.head()
# Out:
#              Timestamp          Node Subsystem Sensor_Name  Measurement  \
# 0  2019/07/18 14:00:00  001e0610ee36  metsense     pr103j2  temperature
# 1  2019/07/18 14:00:00  001e06114fd4  metsense     pr103j2  temperature
# 2  2019/07/18 14:00:01  001e0610ba13  metsense     pr103j2  temperature
# 3  2019/07/18 14:00:02  001e0610ee61  metsense     pr103j2  temperature
# 4  2019/07/18 14:00:02  001e06113ad8  metsense     pr103j2  temperature
#
#    Raw_Value  Human_Readable
# 0        840           24.45
# 1        839           24.30
# 2        853           26.45
# 3        850           26.00
# 4        837           24.00

# %% [markdown]
# ### What about rows?
#
# Rows are a little trickiier to reference because they are not series. In columns, we can reference the name of the columns that we are interested in. Also, the elements in a column are the same data type. Since rows contain the elements of several series, they can contain multiple data types and require a different way of thinking.
